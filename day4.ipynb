# %%
import pandas as pd
arr=pd.Series([10,20,30,40],name="marks")
print(arr)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# Name: marks, dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
arr=pd.Series([10,20,30,40],index=["english","c","python","java"],name="marks")
print(arr)
# Out:
# english    10
# c          20
# python     30
# java       40
# Name: marks, dtype: int64

# %%
print(arr.loc["c"])
# Out:
# 20

# %%
print(arr.iloc[1])
# Out:
# 20

# %%
print(arr.loc["c":"java"])
# Out:
# c         20
# python    30
# java      40
# Name: marks, dtype: int64

# %%
arr[0]=500
print(arr)
# Out:
# english    500
# c           20
# python      30
# java        40
# Name: marks, dtype: int64
# /tmp/ipykernel_1937/1731888521.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   arr[0]=500

# %%
arr[0:3]=100

# %%
print(arr)
# Out:
# english    100
# c          100
# python     100
# java        40
# Name: marks, dtype: int64

# %%
df=pd.DataFrame([[1,2,3],[4,5,6]])
print(df)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
df=pd.DataFrame([[1,2,3],[4,5,6]],index=["boys","girls"],columns=["english","c","python"])
print(df)
# Out:
#        english  c  python
# boys         1  2       3
# girls        4  5       6

# %%
df=pd.DataFrame({"english":[10,20,30,40],"c":[100,200,300,400],"python":[1000,2000,3000,4000]},index=["cls-1","cls-2","cls-3","cls-4"])
print(df)
# Out:
#        english    c  python
# cls-1       10  100    1000
# cls-2       20  200    2000
# cls-3       30  300    3000
# cls-4       40  400    4000

# %%
df["english"]
# Out:
# cls-1    10
# cls-2    20
# cls-3    30
# cls-4    40
# Name: english, dtype: int64

# %%
df.loc["cls-1"]
# Out:
# english      10
# c           100
# python     1000
# Name: cls-1, dtype: int64

# %%
df=pd.DataFrame({"english":[10,20,30,40],"c":[100,200,300,400],"python":[1000,2000,3000,4000]},index=["cls-1","cls-2","cls-3","cls-4"])
print(df)
# Out:
#        english    c  python
# cls-1       10  100    1000
# cls-2       20  200    2000
# cls-3       30  300    3000
# cls-4       40  400    4000

# %%
print(df.index)
# Out:
# Index(['cls-1', 'cls-2', 'cls-3', 'cls-4'], dtype='object')

# %%
print(df.columns)
# Out:
# Index(['english', 'c', 'python'], dtype='object')

# %%
print(df.axes)
# Out:
# [Index(['cls-1', 'cls-2', 'cls-3', 'cls-4'], dtype='object'), Index(['english', 'c', 'python'], dtype='object')]

# %%
print(df.dtypes)
# Out:
# english    int64
# c          int64
# python     int64
# dtype: object

# %%
print(df.shape)
# Out:
# (4, 3)

# %%
print(df.size)
# Out:
# 12

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.empty)
# Out:
# False

# %%
print(df.values)
# Out:
# [[  10  100 1000]
#  [  20  200 2000]
#  [  30  300 3000]
#  [  40  400 4000]]

# %%
df
# Out:
#        english    c  python
# cls-1       10  100    1000
# cls-2       20  200    2000
# cls-3       30  300    3000
# cls-4       40  400    4000

# %%
print(df.T)
# Out:
#          cls-1  cls-2  cls-3  cls-4
# english     10     20     30     40
# c          100    200    300    400
# python    1000   2000   3000   4000

# %%
df_1=pd.DataFrame()
print(df_1.empty)
# Out:
# True

# %%
df.head(2)
# Out:
#        english    c  python
# cls-1       10  100    1000
# cls-2       20  200    2000

# %%
df.tail(2)
# Out:
#        english    c  python
# cls-3       30  300    3000
# cls-4       40  400    4000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, cls-1 to cls-4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   english  4 non-null      int64
#  1   c        4 non-null      int64
#  2   python   4 non-null      int64
# dtypes: int64(3)
# memory usage: 300.0+ bytes

# %%
df.describe()
# Out:
#          english           c       python
# count   4.000000    4.000000     4.000000
# mean   25.000000  250.000000  2500.000000
# std    12.909944  129.099445  1290.994449
# min    10.000000  100.000000  1000.000000
# 25%    17.500000  175.000000  1750.000000
# 50%    25.000000  250.000000  2500.000000
# 75%    32.500000  325.000000  3250.000000
# max    40.000000  400.000000  4000.000000

# %%
df.count()
# Out:
# english    4
# c          4
# python     4
# dtype: int64

# %%
df.size
# Out:
# 12

# %%
df.sample()
# Out:
#        english    c  python
# cls-2       20  200    2000

# %%
a=pd.Series([10,20,30,40])
b=pd.Series([20,30,None])
print(a)

print("================")

print(b)


print("================")

print(a+b)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# ...
# 0    20.0
# 1    30.0
# 2     NaN
# dtype: float64
# ...
# 0    30.0
# 1    50.0
# 2     NaN
# 3     NaN
# dtype: float64

# %%
c=a+b
print(c)
# Out:
# 0    30.0
# 1    50.0
# 2     NaN
# 3     NaN
# dtype: float64

# %%
c=a.add(b,fill_value=0)
print(c)
# Out:
# 0    30.0
# 1    50.0
# 2    30.0
# 3    40.0
# dtype: float64

# %%
c=a-b
print(c)
# Out:
# 0   -10.0
# 1   -10.0
# 2     NaN
# 3     NaN
# dtype: float64

# %%
c=a.sub(b,fill_value=0)
print(c)
# Out:
# 0   -10.0
# 1   -10.0
# 2    30.0
# 3    40.0
# dtype: float64

# %%
import pandas as pd
df1=pd.DataFrame({"name":["ram","sam"],"age":[20,21]})
df2=pd.DataFrame({"name":["arati","rutika"],"age":[22,23]})
result=pd.concat([df1,df2])
print(result)
# Out:
#      name  age
# 0     ram   20
# 1     sam   21
# 0   arati   22
# 1  rutika   23

# %%
import pandas as pd
df1=pd.DataFrame({"name":["ram","sam"],"age":[20,21]})
df2=pd.DataFrame({"name":["arati","rutika"],"age":[22,23]})
result=pd.concat([df1,df2],ignore_index=True)
print(result)
# Out:
#      name  age
# 0     ram   20
# 1     sam   21
# 2   arati   22
# 3  rutika   23

# %%
df.head(1)
# Out:
#        english    c  python
# cls-1       10  100    1000

# %%
df=pd.read_csv("/content/std.csv",header=None)
print(df)
# Out:
#                                                     0
# 0   | Roll No | Name           | Age | Gender | Cl...
# 1   | ------: | -------------- | --: | ------ | --...
# 2   |       1 | Aarav Sharma   |  15 | Male   | 10...
# 3   |       2 | Ananya Patel   |  15 | Female | 10...
# 4   |       3 | Rohan Gupta    |  16 | Male   | 10...
# 5   |       4 | Priya Singh    |  15 | Female | 10...
# 6   |       5 | Arjun Kumar    |  15 | Male   | 10...
# 7   |       6 | Sneha Verma    |  16 | Female | 10...
# 8   |       7 | Rahul Joshi    |  15 | Male   | 10...
# 9   |       8 | Neha Reddy     |  15 | Female | 10...
# 10  |       9 | Karan Mehta    |  16 | Male   | 10...
# 11  |      10 | Pooja Nair     |  15 | Female | 10...
# 12  |      11 | Aditya Rao     |  15 | Male   | 10...
# 13  |      12 | Isha Kapoor    |  16 | Female | 10...
# 14  |      13 | Vivek Das      |  15 | Male   | 10...
# 15  |      14 | Kavya Iyer     |  15 | Female | 10...
# ...

# %%
df=pd.read_excel("/content/std2.xlsx")
df
# Out:
#    Unnamed: 0      Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     Roll No            Name        Age     Gender      Class    Section
# 1           1    Aarav Sharma         15       Male         10          A
# 2           2    Ananya Patel         15     Female         10          A
# 3           3     Rohan Gupta         16       Male         10          A
# 4           4     Priya Singh         15     Female         10          A
# 5           5     Arjun Kumar         15       Male         10          A
# 6           6     Sneha Verma         16     Female         10          A
# 7           7     Rahul Joshi         15       Male         10          A
# 8           8      Neha Reddy         15     Female         10          A
# 9           9     Karan Mehta         16       Male         10          A
# 10         10      Pooja Nair         15     Female         10          A
# 11         11      Aditya Rao         15       Male         10          B
# ...

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=51, step=1)

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=51, step=1), Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')]

# %%
print(df.dtypes)
# Out:
# Unnamed: 0    object
# Unnamed: 1    object
# Unnamed: 2    object
# Unnamed: 3    object
# Unnamed: 4    object
# Unnamed: 5    object
# Unnamed: 6    object
# Unnamed: 7    object
# Unnamed: 8    object
# Unnamed: 9    object
# dtype: object

# %%
print(df.size)
# Out:
# 510

# %%
print(df.shape)
# Out:
# (51, 10)

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.empty)
# Out:
# False

# %%
print(df.T)
# Out:
#                  0             1             2            3            4   \
# Unnamed: 0  Roll No             1             2            3            4
# Unnamed: 1     Name  Aarav Sharma  Ananya Patel  Rohan Gupta  Priya Singh
# Unnamed: 2      Age            15            15           16           15
# Unnamed: 3   Gender          Male        Female         Male       Female
# Unnamed: 4    Class            10            10           10           10
# Unnamed: 5  Section             A             A            A            A
# Unnamed: 6     Math            85            92           78           89
# Unnamed: 7  Science            88            95           80           87
# Unnamed: 8  English            90            91           82           93
# Unnamed: 9    Total           263           278          240          269
#
#                      5            6            7           8            9   \
# Unnamed: 0            5            6            7           8            9
# ...

# %%
print(df.values)
# Out:
# [['Roll No' 'Name' 'Age' 'Gender' 'Class' 'Section' 'Math' 'Science'
#   'English' 'Total']
#  [1 'Aarav Sharma' 15 'Male' 10 'A' 85 88 90 263]
#  [2 'Ananya Patel' 15 'Female' 10 'A' 92 95 91 278]
#  [3 'Rohan Gupta' 16 'Male' 10 'A' 78 80 82 240]
#  [4 'Priya Singh' 15 'Female' 10 'A' 89 87 93 269]
#  [5 'Arjun Kumar' 15 'Male' 10 'A' 76 79 75 230]
#  [6 'Sneha Verma' 16 'Female' 10 'A' 94 91 95 280]
#  [7 'Rahul Joshi' 15 'Male' 10 'A' 68 72 70 210]
#  [8 'Neha Reddy' 15 'Female' 10 'A' 81 84 86 251]
#  [9 'Karan Mehta' 16 'Male' 10 'A' 88 85 87 260]
#  [10 'Pooja Nair' 15 'Female' 10 'A' 90 89 92 271]
#  [11 'Aditya Rao' 15 'Male' 10 'B' 73 77 74 224]
#  [12 'Isha Kapoor' 16 'Female' 10 'B' 95 96 94 285]
#  [13 'Vivek Das' 15 'Male' 10 'B' 84 82 80 246]
#  [14 'Kavya Iyer' 15 'Female' 10 'B' 91 90 89 270]
#  [15 'Manish Yadav' 16 'Male' 10 'B' 69 71 68 208]
#  [16 'Divya Mishra' 15 'Female' 10 'B' 87 89 90 266]
#  [17 'Nikhil Jain' 15 'Male' 10 'B' 79 81 83 243]
# ...

# %%
df.head(5)
# Out:
#   Unnamed: 0    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0    Roll No          Name        Age     Gender      Class    Section
# 1          1  Aarav Sharma         15       Male         10          A
# 2          2  Ananya Patel         15     Female         10          A
# 3          3   Rohan Gupta         16       Male         10          A
# 4          4   Priya Singh         15     Female         10          A
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0       Math    Science    English      Total
# 1         85         88         90        263
# 2         92         95         91        278
# 3         78         80         82        240
# 4         89         87         93        269

# %%
df.tail()
# Out:
#    Unnamed: 0     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 46         46  Nikita Sharma         15     Female         10          E
# 47         47   Pranav Nanda         15       Male         10          E
# 48         48  Radhika Joshi         16     Female         10          E
# 49         49    Dev Malviya         15       Male         10          E
# 50         50   Shruti Patil         15     Female         10          E
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 46         93         92         94        279
# 47         70         72         71        213
# 48         90         89         91        270
# 49         82         83         84        249
# 50         95         94         96        285

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  51 non-null     object
#  1   Unnamed: 1  51 non-null     object
#  2   Unnamed: 2  51 non-null     object
#  3   Unnamed: 3  51 non-null     object
#  4   Unnamed: 4  51 non-null     object
#  5   Unnamed: 5  51 non-null     object
#  6   Unnamed: 6  51 non-null     object
#  7   Unnamed: 7  51 non-null     object
#  8   Unnamed: 8  51 non-null     object
#  9   Unnamed: 9  51 non-null     object
# dtypes: object(10)
# memory usage: 4.1+ KB

# %%
df.count()
# Out:
# Unnamed: 0    51
# Unnamed: 1    51
# Unnamed: 2    51
# Unnamed: 3    51
# Unnamed: 4    51
# Unnamed: 5    51
# Unnamed: 6    51
# Unnamed: 7    51
# Unnamed: 8    51
# Unnamed: 9    51
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# count          51         51          51         51          51         51
# unique         51         51           3          3           2          6
# top       Roll No       Name          15       Male          10          A
# freq            1          1          34         25          50         10
#
#         Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# count           51          51          51          51
# unique          31          27          28          37
# top             89          89          90         285
# freq             3           4           4           3

# %%
df.loc[0:10]
# Out:
#    Unnamed: 0    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     Roll No          Name        Age     Gender      Class    Section
# 1           1  Aarav Sharma         15       Male         10          A
# 2           2  Ananya Patel         15     Female         10          A
# 3           3   Rohan Gupta         16       Male         10          A
# 4           4   Priya Singh         15     Female         10          A
# 5           5   Arjun Kumar         15       Male         10          A
# 6           6   Sneha Verma         16     Female         10          A
# 7           7   Rahul Joshi         15       Male         10          A
# 8           8    Neha Reddy         15     Female         10          A
# 9           9   Karan Mehta         16       Male         10          A
# 10         10    Pooja Nair         15     Female         10          A
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        Math    Science    English      Total
# ...

# %%
import pandas as pd
df=pd.read_csv(r"/content/std2.csv")
df.head()
# Out:
#   Purchase_ID Customer_ID Purchase_Date    Brand          Model  Color  \
# 0        P001       C1001    2025-01-05  Samsung     Galaxy A54  Black
# 1        P002       C1002    2025-01-08    Apple      iPhone 15   Blue
# 2        P003       C1003    2025-01-10   Xiaomi  Redmi Note 13  Green
# 3        P004       C1004    2025-01-12  OnePlus      Nord CE 4   Gray
# 4        P005       C1005    2025-01-15   Google        Pixel 8  Black
#
#    RAM_GB  Storage_GB  Price_USD Payment_Method Purchase_Channel  \
# 0       8         128        399    Credit Card           Online
# 1       6         128        799     Debit Card            Store
# 2       8         256        249            UPI           Online
# 3       8         256        329           Cash            Store
# 4       8         128        699    Credit Card           Online
#
#    Warranty_Years  Discount_Percent  Final_Amount  Customer_Rating
# 0               2                10        359.10                5
# ...

# %%
df.head()
# Out:
#   Purchase_ID Customer_ID Purchase_Date    Brand          Model  Color  \
# 0        P001       C1001    2025-01-05  Samsung     Galaxy A54  Black
# 1        P002       C1002    2025-01-08    Apple      iPhone 15   Blue
# 2        P003       C1003    2025-01-10   Xiaomi  Redmi Note 13  Green
# 3        P004       C1004    2025-01-12  OnePlus      Nord CE 4   Gray
# 4        P005       C1005    2025-01-15   Google        Pixel 8  Black
#
#    RAM_GB  Storage_GB  Price_USD Payment_Method Purchase_Channel  \
# 0       8         128        399    Credit Card           Online
# 1       6         128        799     Debit Card            Store
# 2       8         256        249            UPI           Online
# 3       8         256        329           Cash            Store
# 4       8         128        699    Credit Card           Online
#
#    Warranty_Years  Discount_Percent  Final_Amount  Customer_Rating
# 0               2                10        359.10                5
# ...

# %%
df.tail()
# Out:
#    Purchase_ID Customer_ID Purchase_Date     Brand       Model  Color  RAM_GB  \
# 45        P046       C1046    2025-05-17  Motorola         G34  Black       8
# 46        P047       C1047    2025-05-20    Realme     12 Pro+   Gold      12
# 47        P048       C1048    2025-05-23      Vivo         Y28  Green       8
# 48        P049       C1049    2025-05-26      Oppo         A60   Blue       8
# 49        P050       C1050    2025-05-29   Nothing  Phone (2a)  White      12
#
#     Storage_GB  Price_USD Payment_Method Purchase_Channel  Warranty_Years  \
# 45         128        199           Cash           Online               1
# 46         256        429    Credit Card            Store               2
# 47         128        229            UPI           Online               1
# 48         256        219           Cash            Store               1
# 49         256        379    Credit Card           Online               2
#
#     Discount_Percent  Final_Amount  Customer_Rating
# ...

# %%
df.describe()
# Out:
#           RAM_GB  Storage_GB    Price_USD  Warranty_Years  Discount_Percent  \
# count  50.000000   50.000000    50.000000       50.000000         50.000000
# mean    9.280000  217.600000   508.200000        1.600000          9.140000
# std     3.326087  109.714286   359.272735        0.494872          3.057343
# min     4.000000   64.000000   129.000000        1.000000          5.000000
# 25%     8.000000  128.000000   264.000000        1.000000          7.000000
# 50%     8.000000  256.000000   399.000000        2.000000         10.000000
# 75%    12.000000  256.000000   674.000000        2.000000         10.000000
# max    16.000000  512.000000  1799.000000        2.000000         15.000000
#
#        Final_Amount  Customer_Rating
# count      50.00000        50.000000
# mean      457.99340         4.440000
# std       312.57855         0.611455
# min       122.55000         3.000000
# 25%       248.07500         4.000000
# 50%       359.10000         4.500000
# ...

# %%
df.count()
# Out:
# Purchase_ID         50
# Customer_ID         50
# Purchase_Date       50
# Brand               50
# Model               50
# Color               50
# RAM_GB              50
# Storage_GB          50
# Price_USD           50
# Payment_Method      50
# Purchase_Channel    50
# Warranty_Years      50
# Discount_Percent    50
# Final_Amount        50
# Customer_Rating     50
# dtype: int64

# %%
df.ndim
# Out:
# 2

# %%
df["Brand"].unique()
# Out:
# array(['Samsung', 'Apple', 'Xiaomi', 'OnePlus', 'Google', 'Motorola',
#        'Realme', 'Vivo', 'Oppo', 'Nokia', '14 Ultra', 'Nothing'],
#       dtype=object)

# %%
df["Model"].unique()
# Out:
# array(['Galaxy A54', 'iPhone 15', 'Redmi Note 13', 'Nord CE 4', 'Pixel 8',
#        'G54', 'Narzo 70', 'V30', 'Reno 11', 'G42', 'Galaxy S24',
#        'iPhone 14', 'Poco X6', '12R', 'Pixel 7a', 'Edge 50', 'GT 6T',
#        'T3', 'F27 Pro', 'C32', 'Galaxy M35', 'iPhone SE', 'Redmi 13C',
#        'Nord 3', 'Pixel Fold', 'Moto G84', 'C67', 'Y200', 'A79', 'X30',
#        'Galaxy Z Flip6', 'iPhone 15 Pro', '2025-04-07', 'Open', 'Pixel 9',
#        'Razr 50', 'P1', 'X100', 'Find X7', 'G22', 'Galaxy A35',
#        'iPhone 13', 'Poco F6', 'Nord N30', 'Pixel 8a', 'G34', '12 Pro+',
#        'Y28', 'A60', 'Phone (2a)'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Purchase_ID       50 non-null     object
#  1   Customer_ID       50 non-null     object
#  2   Purchase_Date     50 non-null     object
#  3   Brand             50 non-null     object
#  4   Model             50 non-null     object
#  5   Color             50 non-null     object
#  6   RAM_GB            50 non-null     int64
#  7   Storage_GB        50 non-null     int64
#  8   Price_USD         50 non-null     int64
#  9   Payment_Method    50 non-null     object
#  10  Purchase_Channel  50 non-null     object
#  11  Warranty_Years    50 non-null     int64
#  12  Discount_Percent  50 non-null     int64
#  13  Final_Amount      50 non-null     float64
#  14  Customer_Rating   50 non-null     int64
# dtypes: float64(1), int64(6), object(8)
# memory usage: 6.0+ KB

# %%
df[df["Brand"].isin(["Nothing","Oppo"])]
# Out:
#    Purchase_ID Customer_ID Purchase_Date    Brand       Model  Color  RAM_GB  \
# 8         P009       C1009    2025-01-25     Oppo     Reno 11  White       8
# 18        P019       C1019    2025-02-23     Oppo     F27 Pro  Green       8
# 28        P029       C1029    2025-03-24     Oppo         A79  Black       8
# 38        P039       C1039    2025-04-25     Oppo     Find X7  White      16
# 48        P049       C1049    2025-05-26     Oppo         A60   Blue       8
# 49        P050       C1050    2025-05-29  Nothing  Phone (2a)  White      12
#
#     Storage_GB  Price_USD Payment_Method Purchase_Channel  Warranty_Years  \
# 8          256        379            UPI           Online               2
# 18         256        349    Credit Card           Online               2
# 28         128        249    Credit Card           Online               2
# 38         512        999            UPI            Store               2
# ...

# %%
df[df["Price_USD"].between(249,349)]
# Out:
#    Purchase_ID Customer_ID Purchase_Date     Brand          Model   Color  \
# 2         P003       C1003    2025-01-10    Xiaomi  Redmi Note 13   Green
# 3         P004       C1004    2025-01-12   OnePlus      Nord CE 4    Gray
# 12        P013       C1013    2025-02-06    Xiaomi        Poco X6    Blue
# 17        P018       C1018    2025-02-20      Vivo             T3    Blue
# 18        P019       C1019    2025-02-23      Oppo        F27 Pro   Green
# 20        P021       C1021    2025-03-01   Samsung     Galaxy M35    Blue
# 25        P026       C1026    2025-03-15  Motorola       Moto G84    Blue
# 27        P028       C1028    2025-03-21      Vivo           Y200  Purple
# 28        P029       C1029    2025-03-24      Oppo            A79   Black
# 36        P037       C1037    2025-04-19    Realme             P1   Green
# 40        P041       C1041    2025-05-02   Samsung     Galaxy A35    Blue
# 43        P044       C1044    2025-05-11   OnePlus       Nord N30    Gray
#
# ...
