# %%
import pandas as pd
import numpy as np
student={
    "id":[101,102,103,104,105],"name":["anuu","sujji",np.nan,"sneha","kiran"],
    "department":["BCA","BCA","BSc",np.nan,"BCA"],
    "marks":[85,np.nan,78,92,80]
}
print(type(student))
df=pd.DataFrame(student)
print(df)
# Out:
# <class 'dict'>
#     id   name department  marks
# 0  101   anuu        BCA   85.0
# 1  102  sujji        BCA    NaN
# 2  103    NaN        BSc   78.0
# 3  104  sneha        NaN   92.0
# 4  105  kiran        BCA   80.0

# %%
df.isnull()
# Out:
#       id   name  department  marks
# 0  False  False       False  False
# 1  False  False       False   True
# 2  False   True       False  False
# 3  False  False        True  False
# 4  False  False       False  False

# %%
df.notnull()
# Out:
#      id   name  department  marks
# 0  True   True        True   True
# 1  True   True        True  False
# 2  True  False        True   True
# 3  True   True       False   True
# 4  True   True        True   True

# %%
print(df.fillna("unknown"))
# Out:
#     id     name department    marks
# 0  101     anuu        BCA     85.0
# 1  102    sujji        BCA  unknown
# 2  103  unknown        BSc     78.0
# 3  104    sneha    unknown     92.0
# 4  105    kiran        BCA     80.0

# %%
df["marks"]=df["marks"].fillna(0)
print(df)
# Out:
#     id   name department  marks
# 0  101   anuu        BCA   85.0
# 1  102  sujji        BCA    0.0
# 2  103    NaN        BSc   78.0
# 3  104  sneha        NaN   92.0
# 4  105  kiran        BCA   80.0

# %%
import pandas as pd
import numpy as np
student={
    "id":[101,102,103,104,105],"name":["anuu","sujji",np.nan,"sneha","kiran"],
    "department":["BCA","BCA","BSc",np.nan,"BCA"],
    "marks":[85,np.nan,78,92,80]
}
df=pd.DataFrame(student)
print(df)
# Out:
#     id   name department  marks
# 0  101   anuu        BCA   85.0
# 1  102  sujji        BCA    NaN
# 2  103    NaN        BSc   78.0
# 3  104  sneha        NaN   92.0
# 4  105  kiran        BCA   80.0

# %%
df.dropna()
# Out:
#     id   name department  marks
# 0  101   anuu        BCA   85.0
# 4  105  kiran        BCA   80.0

# %%
import pandas as pd
df=pd.read_csv(r"/content/cricket.csv")
df.head()
# Out:
#       match_id  match_date  season team opponent            player  runs  \
# 0  IPL2025_001  2025-03-22    2025  CSK       MI   Ruturaj Gaikwad    78
# 1  IPL2025_001  2025-03-22    2025  CSK       MI       Shivam Dube    45
# 2  IPL2025_001  2025-03-22    2025   MI      CSK      Rohit Sharma    66
# 3  IPL2025_001  2025-03-22    2025   MI      CSK  Suryakumar Yadav    74
# 4  IPL2025_002  2025-03-23    2025  RCB      KKR       Virat Kohli   114
#
#    match_total century
# 0          198      No
# 1          198      No
# 2          186      No
# 3          186      No
# 4          221     Yes

# %%
df["player"].value_counts()
# Out:
# player
# Ruturaj Gaikwad     2
# Virat Kohli         2
# Abhishek Sharma     2
# Rohit Sharma        1
# Suryakumar Yadav    1
# Rajat Patidar       1
# Shivam Dube         1
# Andre Russell       1
# Travis Head         1
# Heinrich Klaasen    1
# Yashasvi Jaiswal    1
# Sanju Samson        1
# Shubman Gill        1
# David Miller        1
# Shreyas Iyer        1
# Rishabh Pant        1
# David Warner        1
# Nicholas Pooran     1
# KL Rahul            1
# Liam Livingstone    1
# Sunil Narine        1
# Rinku Singh         1
# Shikhar Dhawan      1
# MS Dhoni            1
# Jos Buttler         1
# Riyan Parag         1
# Faf du Plessis      1
# Glenn Maxwell       1
# Ishan Kishan        1
# Hardik Pandya       1
# Ravindra Jadeja     1
# Sai Sudharsan       1
# Rahul Tewatia       1
# Prithvi Shaw        1
# Axar Patel          1
# Aiden Markram       1
# Jitesh Sharma       1
# Sam Curran          1
# Tilak Varma         1
# Tim David           1
# Rachin Ravindra     1
# ...

# %%
df["player"].unique()
# Out:
# array(['Ruturaj Gaikwad', 'Shivam Dube', 'Rohit Sharma',
#        'Suryakumar Yadav', 'Virat Kohli', 'Rajat Patidar', 'Shreyas Iyer',
#        'Andre Russell', 'Travis Head', 'Heinrich Klaasen',
#        'Yashasvi Jaiswal', 'Sanju Samson', 'Shubman Gill', 'David Miller',
#        'Rishabh Pant', 'David Warner', 'KL Rahul', 'Nicholas Pooran',
#        'Shikhar Dhawan', 'Liam Livingstone', 'Sunil Narine',
#        'Rinku Singh', 'Ravindra Jadeja', 'MS Dhoni', 'Jos Buttler',
#        'Riyan Parag', 'Faf du Plessis', 'Glenn Maxwell', 'Ishan Kishan',
#        'Hardik Pandya', 'Sai Sudharsan', 'Rahul Tewatia', 'Prithvi Shaw',
#        'Axar Patel', 'Abhishek Sharma', 'Aiden Markram', 'Jitesh Sharma',
#        'Sam Curran', 'Tilak Varma', 'Tim David', 'Rachin Ravindra',
#        'Daryl Mitchell', 'Wriddhiman Saha', 'Rashid Khan',
#        'Cameron Green', 'Quinton de Kock', 'Marcus Stoinis'], dtype=object)

# %%
df["player"].nunique()
# Out:
# 47

# %%
import pandas as pd
df=pd.read_csv(r"/content/cricket.csv")
df
# Out:
#        match_id  match_date  season  team opponent            player  runs  \
# 0   IPL2025_001  2025-03-22    2025   CSK       MI   Ruturaj Gaikwad    78
# 1   IPL2025_001  2025-03-22    2025   CSK       MI       Shivam Dube    45
# 2   IPL2025_001  2025-03-22    2025    MI      CSK      Rohit Sharma    66
# 3   IPL2025_001  2025-03-22    2025    MI      CSK  Suryakumar Yadav    74
# 4   IPL2025_002  2025-03-23    2025   RCB      KKR       Virat Kohli   114
# 5   IPL2025_002  2025-03-23    2025   RCB      KKR     Rajat Patidar    43
# 6   IPL2025_002  2025-03-23    2025   KKR      RCB      Shreyas Iyer    71
# 7   IPL2025_002  2025-03-23    2025   KKR      RCB     Andre Russell    58
# 8   IPL2025_003  2025-03-24    2025   SRH       RR       Travis Head   103
# 9   IPL2025_003  2025-03-24    2025   SRH       RR  Heinrich Klaasen    68
# 10  IPL2025_003  2025-03-24    2025    RR      SRH  Yashasvi Jaiswal    91
# ...

# %%
df.head()
# Out:
#       match_id  match_date  season team opponent            player  runs  \
# 0  IPL2025_001  2025-03-22    2025  CSK       MI   Ruturaj Gaikwad    78
# 1  IPL2025_001  2025-03-22    2025  CSK       MI       Shivam Dube    45
# 2  IPL2025_001  2025-03-22    2025   MI      CSK      Rohit Sharma    66
# 3  IPL2025_001  2025-03-22    2025   MI      CSK  Suryakumar Yadav    74
# 4  IPL2025_002  2025-03-23    2025  RCB      KKR       Virat Kohli   114
#
#    match_total century
# 0          198      No
# 1          198      No
# 2          186      No
# 3          186      No
# 4          221     Yes

# %%
df.tail()
# Out:
#        match_id  match_date  season team opponent           player  runs  \
# 45  IPL2025_012  2025-04-02    2025  RCB      LSG    Cameron Green    57
# 46  IPL2025_012  2025-04-02    2025  LSG      RCB  Quinton de Kock    81
# 47  IPL2025_012  2025-04-02    2025  LSG      RCB   Marcus Stoinis    65
# 48  IPL2025_013  2025-04-03    2025  SRH      CSK  Abhishek Sharma   112
# 49  IPL2025_013  2025-04-03    2025  CSK      SRH  Ruturaj Gaikwad    88
#
#     match_total century
# 45          218      No
# 46          206      No
# 47          206      No
# 48          239     Yes
# 49          214      No

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   match_id     50 non-null     object
#  1   match_date   50 non-null     object
#  2   season       50 non-null     int64
#  3   team         50 non-null     object
#  4   opponent     50 non-null     object
#  5   player       50 non-null     object
#  6   runs         50 non-null     int64
#  7   match_total  50 non-null     int64
#  8   century      50 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 3.6+ KB

# %%
df.describe()
# Out:
#        season        runs  match_total
# count    50.0   50.000000    50.000000
# mean   2025.0   69.700000   209.380000
# std       0.0   22.127875    12.750174
# min    2025.0   29.000000   186.000000
# 25%    2025.0   52.500000   201.000000
# 50%    2025.0   67.000000   207.000000
# 75%    2025.0   85.500000   217.500000
# max    2025.0  114.000000   239.000000

# %%
df.count()
# Out:
# match_id       50
# match_date     50
# season         50
# team           50
# opponent       50
# player         50
# runs           50
# match_total    50
# century        50
# dtype: int64

# %%
avg=df["runs"].mean()

# %%
df.size
# Out:
# 450

# %%
df.shape
# Out:
# (50, 9)

# %%
df.columns
# Out:
# Index(['match_id', 'match_date', 'season', 'team', 'opponent', 'player',
#        'runs', 'match_total', 'century'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=50, step=1),
#  Index(['match_id', 'match_date', 'season', 'team', 'opponent', 'player',
#         'runs', 'match_total', 'century'],
#        dtype='object')]

# %%
df.dtypes
# Out:
# match_id       object
# match_date     object
# season          int64
# team           object
# opponent       object
# player         object
# runs            int64
# match_total     int64
# century        object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.T
# Out:
#                           0            1             2                 3   \
# match_id         IPL2025_001  IPL2025_001   IPL2025_001       IPL2025_001
# match_date        2025-03-22   2025-03-22    2025-03-22        2025-03-22
# season                  2025         2025          2025              2025
# team                     CSK          CSK            MI                MI
# opponent                  MI           MI           CSK               CSK
# player       Ruturaj Gaikwad  Shivam Dube  Rohit Sharma  Suryakumar Yadav
# runs                      78           45            66                74
# match_total              198          198           186               186
# century                   No           No            No                No
#
#                       4              5             6              7   \
# match_id     IPL2025_002    IPL2025_002   IPL2025_002    IPL2025_002
# match_date    2025-03-23     2025-03-23    2025-03-23     2025-03-23
# ...

# %%
df.empty
# Out:
# False

# %%
df.values
# Out:
# array([['IPL2025_001', '2025-03-22', 2025, 'CSK', 'MI',
#         'Ruturaj Gaikwad', 78, 198, 'No'],
#        ['IPL2025_001', '2025-03-22', 2025, 'CSK', 'MI', 'Shivam Dube',
#         45, 198, 'No'],
#        ['IPL2025_001', '2025-03-22', 2025, 'MI', 'CSK', 'Rohit Sharma',
#         66, 186, 'No'],
#        ['IPL2025_001', '2025-03-22', 2025, 'MI', 'CSK',
#         'Suryakumar Yadav', 74, 186, 'No'],
#        ['IPL2025_002', '2025-03-23', 2025, 'RCB', 'KKR', 'Virat Kohli',
#         114, 221, 'Yes'],
#        ['IPL2025_002', '2025-03-23', 2025, 'RCB', 'KKR', 'Rajat Patidar',
#         43, 221, 'No'],
#        ['IPL2025_002', '2025-03-23', 2025, 'KKR', 'RCB', 'Shreyas Iyer',
#         71, 205, 'No'],
#        ['IPL2025_002', '2025-03-23', 2025, 'KKR', 'RCB', 'Andre Russell',
#         58, 205, 'No'],
#        ['IPL2025_003', '2025-03-24', 2025, 'SRH', 'RR', 'Travis Head',
#         103, 234, 'Yes'],
#        ['IPL2025_003', '2025-03-24', 2025, 'SRH', 'RR',
# ...

# %%
df.head()
# Out:
#     id   name department  marks
# 0  101   anuu        BCA   85.0
# 1  102  sujji        BCA    NaN
# 2  103    NaN        BSc   78.0
# 3  104  sneha        NaN   92.0
# 4  105  kiran        BCA   80.0

# %%
df.rename(columns={"player":"cricketer"})
# Out:
#        match_id  match_date  season  team opponent         cricketer  runs  \
# 0   IPL2025_001  2025-03-22    2025   CSK       MI   Ruturaj Gaikwad    78
# 1   IPL2025_001  2025-03-22    2025   CSK       MI       Shivam Dube    45
# 2   IPL2025_001  2025-03-22    2025    MI      CSK      Rohit Sharma    66
# 3   IPL2025_001  2025-03-22    2025    MI      CSK  Suryakumar Yadav    74
# 4   IPL2025_002  2025-03-23    2025   RCB      KKR       Virat Kohli   114
# 5   IPL2025_002  2025-03-23    2025   RCB      KKR     Rajat Patidar    43
# 6   IPL2025_002  2025-03-23    2025   KKR      RCB      Shreyas Iyer    71
# 7   IPL2025_002  2025-03-23    2025   KKR      RCB     Andre Russell    58
# 8   IPL2025_003  2025-03-24    2025   SRH       RR       Travis Head   103
# 9   IPL2025_003  2025-03-24    2025   SRH       RR  Heinrich Klaasen    68
# 10  IPL2025_003  2025-03-24    2025    RR      SRH  Yashasvi Jaiswal    91
# ...

# %%
df.notnull()
# Out:
#     match_id  match_date  season  team  opponent  player  runs  match_total  \
# 0       True        True    True  True      True    True  True         True
# 1       True        True    True  True      True    True  True         True
# 2       True        True    True  True      True    True  True         True
# 3       True        True    True  True      True    True  True         True
# 4       True        True    True  True      True    True  True         True
# 5       True        True    True  True      True    True  True         True
# 6       True        True    True  True      True    True  True         True
# 7       True        True    True  True      True    True  True         True
# 8       True        True    True  True      True    True  True         True
# 9       True        True    True  True      True    True  True         True
# 10      True        True    True  True      True    True  True         True
# ...

# %%
print(df.fillna("unknown"))
# Out:
#        match_id  match_date  season  team opponent            player  runs  \
# 0   IPL2025_001  2025-03-22    2025   CSK       MI   Ruturaj Gaikwad    78
# 1   IPL2025_001  2025-03-22    2025   CSK       MI       Shivam Dube    45
# 2   IPL2025_001  2025-03-22    2025    MI      CSK      Rohit Sharma    66
# 3   IPL2025_001  2025-03-22    2025    MI      CSK  Suryakumar Yadav    74
# 4   IPL2025_002  2025-03-23    2025   RCB      KKR       Virat Kohli   114
# 5   IPL2025_002  2025-03-23    2025   RCB      KKR     Rajat Patidar    43
# 6   IPL2025_002  2025-03-23    2025   KKR      RCB      Shreyas Iyer    71
# 7   IPL2025_002  2025-03-23    2025   KKR      RCB     Andre Russell    58
# 8   IPL2025_003  2025-03-24    2025   SRH       RR       Travis Head   103
# 9   IPL2025_003  2025-03-24    2025   SRH       RR  Heinrich Klaasen    68
# 10  IPL2025_003  2025-03-24    2025    RR      SRH  Yashasvi Jaiswal    91
# ...

# %%
df.dropna()
# Out:
#        match_id  match_date  season  team opponent            player  runs  \
# 0   IPL2025_001  2025-03-22    2025   CSK       MI   Ruturaj Gaikwad    78
# 1   IPL2025_001  2025-03-22    2025   CSK       MI       Shivam Dube    45
# 2   IPL2025_001  2025-03-22    2025    MI      CSK      Rohit Sharma    66
# 3   IPL2025_001  2025-03-22    2025    MI      CSK  Suryakumar Yadav    74
# 4   IPL2025_002  2025-03-23    2025   RCB      KKR       Virat Kohli   114
# 5   IPL2025_002  2025-03-23    2025   RCB      KKR     Rajat Patidar    43
# 6   IPL2025_002  2025-03-23    2025   KKR      RCB      Shreyas Iyer    71
# 7   IPL2025_002  2025-03-23    2025   KKR      RCB     Andre Russell    58
# 8   IPL2025_003  2025-03-24    2025   SRH       RR       Travis Head   103
# 9   IPL2025_003  2025-03-24    2025   SRH       RR  Heinrich Klaasen    68
# 10  IPL2025_003  2025-03-24    2025    RR      SRH  Yashasvi Jaiswal    91
# ...

# %%
df.isnull()
# Out:
#     match_id  match_date  season   team  opponent  player   runs  match_total  \
# 0      False       False   False  False     False   False  False        False
# 1      False       False   False  False     False   False  False        False
# 2      False       False   False  False     False   False  False        False
# 3      False       False   False  False     False   False  False        False
# 4      False       False   False  False     False   False  False        False
# 5      False       False   False  False     False   False  False        False
# 6      False       False   False  False     False   False  False        False
# 7      False       False   False  False     False   False  False        False
# 8      False       False   False  False     False   False  False        False
# 9      False       False   False  False     False   False  False        False
# 10     False       False   False  False     False   False  False        False
# ...

# %%
import pandas as pd
import numpy as np
student={
    "id":[101,102,103,104,105],"name":["anuu","sujji",np.nan,"sneha","kiran"],
    "department":["BCA","BCA","BSc",np.nan,"BCA"],
    "marks":[85,np.nan,78,92,80]
}
df=pd.DataFrame(student)
print(df)
# Out:
#     id   name department  marks
# 0  101   anuu        BCA   85.0
# 1  102  sujji        BCA    NaN
# 2  103    NaN        BSc   78.0
# 3  104  sneha        NaN   92.0
# 4  105  kiran        BCA   80.0

# %%
import pandas as pd
df=pd.read_csv(r"/content/cricket.csv")
df.head()
# Out:
#       match_id  match_date  season team opponent            player  runs  \
# 0  IPL2025_001  2025-03-22    2025  CSK       MI   Ruturaj Gaikwad    78
# 1  IPL2025_001  2025-03-22    2025  CSK       MI       Shivam Dube    45
# 2  IPL2025_001  2025-03-22    2025   MI      CSK      Rohit Sharma    66
# 3  IPL2025_001  2025-03-22    2025   MI      CSK  Suryakumar Yadav    74
# 4  IPL2025_002  2025-03-23    2025  RCB      KKR       Virat Kohli   114
#
#    match_total century
# 0          198      No
# 1          198      No
# 2          186      No
# 3          186      No
# 4          221     Yes

# %%
df[df["player"]=="Virat Kohli"]["team"]
# Out:
# 4     RCB
# 44    RCB
# Name: team, dtype: object

# %%
df.sort_values(by=["runs","match_total"],ascending=[False,True])[["player"]].head(1)
# Out:
#         player
# 4  Virat Kohli

# %%
df.sort_values(by=["runs","match_total"],ascending=[False,True])[["player","runs","match_total"]].head(1)
# Out:
#         player  runs  match_total
# 4  Virat Kohli   114          221

# %%
df.sort_values(by=["runs","match_total"],ascending=[False,True])[["player","runs","match_total"]].tail(1)
# Out:
#          player  runs  match_total
# 43  Rashid Khan    29          199

# %%
df.sort_values(by=["runs","match_total"],ascending=[False,True])[["player","runs","match_total","team"]].head(5)
# Out:
#              player  runs  match_total team
# 4       Virat Kohli   114          221  RCB
# 48  Abhishek Sharma   112          239  SRH
# 16         KL Rahul   108          226  LSG
# 40  Rachin Ravindra   107          231  CSK
# 24      Jos Buttler   105          224   RR

# %%
df.sort_values(by=["runs","match_total"],ascending=[False,True])[["player","runs","match_total","team"]].tail(5)
# Out:
#            player  runs  match_total team
# 31  Rahul Tewatia    42          201   GT
# 39      Tim David    40          202   MI
# 33     Axar Patel    39          208   DC
# 23       MS Dhoni    37          191  CSK
# 43    Rashid Khan    29          199   GT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   match_id     50 non-null     object
#  1   match_date   50 non-null     object
#  2   season       50 non-null     int64
#  3   team         50 non-null     object
#  4   opponent     50 non-null     object
#  5   player       50 non-null     object
#  6   runs         50 non-null     int64
#  7   match_total  50 non-null     int64
#  8   century      50 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 3.6+ KB

# %%
df["runs"].mean()
# Out:
# np.float64(69.7)

# %%
avg_runs=df["runs"].mean()
print(int(avg))
# Out:
# 69

# %%
df["runs"].fillna(int(df["runs"].mean()))
# Out:
# 0      78
# 1      45
# 2      66
# 3      74
# 4     114
# 5      43
# 6      71
# 7      58
# 8     103
# 9      68
# 10     91
# 11     55
# 12     96
# 13     47
# 14     82
# 15     52
# 16    108
# 17     64
# 18     77
# 19     59
# 20     73
# 21     54
# 22     49
# 23     37
# 24    105
# 25     48
# 26     81
# 27     56
# 28     90
# 29     61
# 30     75
# 31     42
# 32     84
# 33     39
# 34     97
# 35     46
# 36     69
# 37     50
# 38     86
# 39     40
# 40    107
# 41     58
# 42     61
# 43     29
# 44     94
# 45     57
# 46     81
# 47     65
# 48    112
# 49     88
# Name: runs, dtype: int64

# %%
df["Wickets"]=df["Wickets"].fillna(int(df["Wickets"].mean()))

# %%
df.head(2)
# Out:
#       match_id  match_date  season team opponent  Wickets           player  \
# 0  IPL2025_001  2025-03-22    2025  CSK       MI        2  Ruturaj Gaikwad
# 1  IPL2025_001  2025-03-22    2025  CSK       MI        3      Shivam Dube
#
#    runs  match_total century
# 0    78          198      No
# 1    45          198      No

# %%
df.columns
# Out:
# Index(['match_id', 'match_date', 'season', 'team', 'opponent', 'Wickets',
#        'player', 'runs', 'match_total', 'century'],
#       dtype='object')

# %%
df[df["team"]=="RCB"]["player"]
# Out:
# 4        Virat Kohli
# 5      Rajat Patidar
# 26    Faf du Plessis
# 27     Glenn Maxwell
# 44       Virat Kohli
# 45     Cameron Green
# Name: player, dtype: object

# %%
df[df["runs"]>70]["player"]
# Out:
# 0      Ruturaj Gaikwad
# 3     Suryakumar Yadav
# 4          Virat Kohli
# 6         Shreyas Iyer
# 8          Travis Head
# 10    Yashasvi Jaiswal
# 12        Shubman Gill
# 14        Rishabh Pant
# 16            KL Rahul
# 18      Shikhar Dhawan
# 20        Sunil Narine
# 24         Jos Buttler
# 26      Faf du Plessis
# 28        Ishan Kishan
# 30       Sai Sudharsan
# 32        Prithvi Shaw
# 34     Abhishek Sharma
# 38         Tilak Varma
# 40     Rachin Ravindra
# 44         Virat Kohli
# 46     Quinton de Kock
# 48     Abhishek Sharma
# 49     Ruturaj Gaikwad
# Name: player, dtype: object

# %%
df[df["runs"]>50][["player","runs"]]
# Out:
#               player  runs
# 0    Ruturaj Gaikwad    78
# 2       Rohit Sharma    66
# 3   Suryakumar Yadav    74
# 4        Virat Kohli   114
# 6       Shreyas Iyer    71
# 7      Andre Russell    58
# 8        Travis Head   103
# 9   Heinrich Klaasen    68
# 10  Yashasvi Jaiswal    91
# 11      Sanju Samson    55
# 12      Shubman Gill    96
# 14      Rishabh Pant    82
# 15      David Warner    52
# 16          KL Rahul   108
# 17   Nicholas Pooran    64
# 18    Shikhar Dhawan    77
# 19  Liam Livingstone    59
# 20      Sunil Narine    73
# 21       Rinku Singh    54
# 24       Jos Buttler   105
# 26    Faf du Plessis    81
# 27     Glenn Maxwell    56
# 28      Ishan Kishan    90
# 29     Hardik Pandya    61
# 30     Sai Sudharsan    75
# 32      Prithvi Shaw    84
# 34   Abhishek Sharma    97
# 36     Jitesh Sharma    69
# 38       Tilak Varma    86
# 40   Rachin Ravindra   107
# 41    Daryl Mitchell    58
# 42   Wriddhiman Saha    61
# 44       Virat Kohli    94
# ...
